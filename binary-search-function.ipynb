# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split


def binary_search(arr,l, h, x):
    if h >= l:
        m = (h + l) // 2
        
        if arr [m] == x:
            return m
        
        elif arr[m] > x:
            return binary_search(arr, l, m - 1, x)
        
        else: 
            return binary_search(arr, m + 1, h, x)
    else: 
        return -1 

arr = [2, 3, 4, 10, 40]
x = int(input("Please enter the element you want to search for:"))

result = binary_search(arr, 0, len(arr)-1,x)

if result != -1:
    print("Element is present at index", str(result))
else:
    print("Element is not present in array")

# %%
#This program can be used for binary searches on created lists, just add the list for x;
#Also works on Dataframes with x = pd.read_csv("input")
